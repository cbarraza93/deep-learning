# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns=["EIN","NAME"])

# %%
# Determine the number of unique values in each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   INCOME_AMT              34299 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  8   ASK_AMT                 34299 non-null  int64
#  9   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.6+ MB

# %%
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
count = df['APPLICATION_TYPE'].value_counts()
print(count)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = df['APPLICATION_TYPE'].value_counts().index[9:]

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classes = df["CLASSIFICATION"].value_counts()
classes
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
df["CLASSIFICATION"].value_counts()[df["CLASSIFICATION"].value_counts()> 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classes[classes < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric = pd.get_dummies(df)
numeric
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric["IS_SUCCESSFUL"]
X = numeric.drop("IS_SUCCESSFUL", axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=44)
X
# Out:
#        STATUS   ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0           1      5000                       0                     1
# 1           1    108590                       0                     0
# 2           1      5000                       0                     0
# 3           1      6692                       0                     0
# 4           1    142590                       0                     0
# ...       ...       ...                     ...                   ...
# 34294       1      5000                       0                     0
# 34295       1      5000                       0                     0
# 34296       1      5000                       0                     0
# 34297       1      5000                       0                     0
# 34298       1  36500179                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = 80, activation = 'relu' , input_dim = 44))


# Second hidden layer
nn.add(tf.keras.layers.Dense(units = 30, activation = 'sigmoid'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                3600
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,061
# Trainable params: 6,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
# Define the checkpoint path and filenames
os.makedirs("checkpoints_ABC/",exist_ok=True)
checkpoint_dir = "checkpoints_ABC/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
from keras.callbacks import Callback
from tensorflow.keras.callbacks import ModelCheckpoint

# Create a callback that saves the model's weights every 5 epochs
checkpoint = ModelCheckpoint(filepath = checkpoint_dir, monitor='loss', verbose=1,
    save_best_only=True, mode='auto', period=5)

# Train the model
fit = nn.fit(X_train_scaled,y_train, epochs=100, callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 804/804 [==============================] - 1s 753us/step - loss: 0.5731 - accuracy: 0.7177
# Epoch 2/100
# 804/804 [==============================] - 1s 729us/step - loss: 0.5543 - accuracy: 0.7312
# Epoch 3/100
# 804/804 [==============================] - 1s 730us/step - loss: 0.5516 - accuracy: 0.7327
# Epoch 4/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5496 - accuracy: 0.7333
# Epoch 5/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5482 - accuracy: 0.7350
# Epoch 5: loss improved from inf to 0.54830, saving model to checkpoints_ABC\weights.05.hdf5
# 804/804 [==============================] - 1s 745us/step - loss: 0.5483 - accuracy: 0.7348
# Epoch 6/100
# 804/804 [==============================] - 1s 737us/step - loss: 0.5478 - accuracy: 0.7323
# Epoch 7/100
# 804/804 [==============================] - 1s 819us/step - loss: 0.5467 - accuracy: 0.7336
# Epoch 8/100
# 804/804 [==============================] - 1s 777us/step - loss: 0.5456 - accuracy: 0.7341
# Epoch 9/100
# 804/804 [==============================] - 1s 775us/step - loss: 0.5449 - accuracy: 0.7343
# Epoch 10/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5450 - accuracy: 0.7334
# Epoch 10: loss improved from 0.54830 to 0.54484, saving model to checkpoints_ABC\weights.10.hdf5
# 804/804 [==============================] - 1s 778us/step - loss: 0.5448 - accuracy: 0.7336
# Epoch 11/100
# 804/804 [==============================] - 1s 743us/step - loss: 0.5443 - accuracy: 0.7350
# Epoch 12/100
# 804/804 [==============================] - 1s 797us/step - loss: 0.5439 - accuracy: 0.7348
# Epoch 13/100
# 804/804 [==============================] - 1s 821us/step - loss: 0.5435 - accuracy: 0.7355
# Epoch 14/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5435 - accuracy: 0.7343
# Epoch 15/100
# 754/804 [===========================>..] - ETA: 0s - loss: 0.5427 - accuracy: 0.7362
# Epoch 15: loss improved from 0.54484 to 0.54282, saving model to checkpoints_ABC\weights.15.hdf5
# 804/804 [==============================] - 1s 784us/step - loss: 0.5428 - accuracy: 0.7354
# Epoch 16/100
# 804/804 [==============================] - 1s 797us/step - loss: 0.5427 - accuracy: 0.7327
# Epoch 17/100
# 804/804 [==============================] - 1s 906us/step - loss: 0.5423 - accuracy: 0.7356
# Epoch 18/100
# 804/804 [==============================] - 1s 864us/step - loss: 0.5420 - accuracy: 0.7355
# Epoch 19/100
# 804/804 [==============================] - 1s 870us/step - loss: 0.5416 - accuracy: 0.7373
# Epoch 20/100
# 771/804 [===========================>..] - ETA: 0s - loss: 0.5418 - accuracy: 0.7363
# Epoch 20: loss improved from 0.54282 to 0.54093, saving model to checkpoints_ABC\weights.20.hdf5
# 804/804 [==============================] - 1s 902us/step - loss: 0.5409 - accuracy: 0.7369
# Epoch 21/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5406 - accuracy: 0.7379
# Epoch 22/100
# 804/804 [==============================] - 1s 817us/step - loss: 0.5404 - accuracy: 0.7365
# Epoch 23/100
# 804/804 [==============================] - 1s 810us/step - loss: 0.5398 - accuracy: 0.7373
# Epoch 24/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5396 - accuracy: 0.7394
# Epoch 25/100
# 772/804 [===========================>..] - ETA: 0s - loss: 0.5396 - accuracy: 0.7380
# Epoch 25: loss improved from 0.54093 to 0.53975, saving model to checkpoints_ABC\weights.25.hdf5
# 804/804 [==============================] - 1s 833us/step - loss: 0.5397 - accuracy: 0.7378
# Epoch 26/100
# 804/804 [==============================] - 1s 801us/step - loss: 0.5393 - accuracy: 0.7378
# Epoch 27/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5392 - accuracy: 0.7382
# Epoch 28/100
# 804/804 [==============================] - 1s 793us/step - loss: 0.5389 - accuracy: 0.7390
# Epoch 29/100
# 804/804 [==============================] - 1s 795us/step - loss: 0.5386 - accuracy: 0.7381
# Epoch 30/100
# 771/804 [===========================>..] - ETA: 0s - loss: 0.5382 - accuracy: 0.7393
# Epoch 30: loss improved from 0.53975 to 0.53839, saving model to checkpoints_ABC\weights.30.hdf5
# 804/804 [==============================] - 1s 821us/step - loss: 0.5384 - accuracy: 0.7384
# Epoch 31/100
# 804/804 [==============================] - 1s 801us/step - loss: 0.5383 - accuracy: 0.7384
# Epoch 32/100
# 804/804 [==============================] - 1s 799us/step - loss: 0.5377 - accuracy: 0.7382
# Epoch 33/100
# 804/804 [==============================] - 1s 808us/step - loss: 0.5378 - accuracy: 0.7387
# Epoch 34/100
# 804/804 [==============================] - 1s 788us/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 35/100
# 722/804 [=========================>....] - ETA: 0s - loss: 0.5362 - accuracy: 0.7395
# Epoch 35: loss improved from 0.53839 to 0.53720, saving model to checkpoints_ABC\weights.35.hdf5
# 804/804 [==============================] - 1s 821us/step - loss: 0.5372 - accuracy: 0.7399
# Epoch 36/100
# 804/804 [==============================] - 1s 943us/step - loss: 0.5369 - accuracy: 0.7397
# Epoch 37/100
# 804/804 [==============================] - 1s 872us/step - loss: 0.5371 - accuracy: 0.7393
# Epoch 38/100
# 804/804 [==============================] - 1s 906us/step - loss: 0.5364 - accuracy: 0.7399
# Epoch 39/100
# 804/804 [==============================] - 1s 868us/step - loss: 0.5365 - accuracy: 0.7407
# Epoch 40/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7408
# Epoch 40: loss improved from 0.53720 to 0.53633, saving model to checkpoints_ABC\weights.40.hdf5
# 804/804 [==============================] - 1s 899us/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 41/100
# 804/804 [==============================] - 1s 873us/step - loss: 0.5359 - accuracy: 0.7405
# Epoch 42/100
# 804/804 [==============================] - 1s 889us/step - loss: 0.5360 - accuracy: 0.7404
# Epoch 43/100
# 804/804 [==============================] - 1s 887us/step - loss: 0.5359 - accuracy: 0.7403
# Epoch 44/100
# 804/804 [==============================] - 1s 881us/step - loss: 0.5355 - accuracy: 0.7404
# Epoch 45/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7403
# Epoch 45: loss improved from 0.53633 to 0.53517, saving model to checkpoints_ABC\weights.45.hdf5
# 804/804 [==============================] - 1s 907us/step - loss: 0.5352 - accuracy: 0.7403
# Epoch 46/100
# 804/804 [==============================] - 1s 896us/step - loss: 0.5353 - accuracy: 0.7396
# Epoch 47/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5353 - accuracy: 0.7393
# Epoch 48/100
# 804/804 [==============================] - 1s 881us/step - loss: 0.5349 - accuracy: 0.7396
# Epoch 49/100
# 804/804 [==============================] - 1s 885us/step - loss: 0.5348 - accuracy: 0.7401
# Epoch 50/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5345 - accuracy: 0.7417
# Epoch 50: loss improved from 0.53517 to 0.53451, saving model to checkpoints_ABC\weights.50.hdf5
# 804/804 [==============================] - 1s 908us/step - loss: 0.5345 - accuracy: 0.7415
# Epoch 51/100
# 804/804 [==============================] - 1s 898us/step - loss: 0.5347 - accuracy: 0.7404
# Epoch 52/100
# 804/804 [==============================] - 1s 890us/step - loss: 0.5342 - accuracy: 0.7405
# Epoch 53/100
# 804/804 [==============================] - 1s 938us/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 54/100
# 804/804 [==============================] - 1s 978us/step - loss: 0.5339 - accuracy: 0.7412
# Epoch 55/100
# 770/804 [===========================>..] - ETA: 0s - loss: 0.5352 - accuracy: 0.7405
# Epoch 55: loss improved from 0.53451 to 0.53393, saving model to checkpoints_ABC\weights.55.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7414
# Epoch 56/100
# 804/804 [==============================] - 1s 976us/step - loss: 0.5338 - accuracy: 0.7406
# Epoch 57/100
# 804/804 [==============================] - 1s 903us/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 58/100
# 804/804 [==============================] - 1s 896us/step - loss: 0.5335 - accuracy: 0.7414
# Epoch 59/100
# 804/804 [==============================] - 1s 936us/step - loss: 0.5334 - accuracy: 0.7416
# Epoch 60/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5333 - accuracy: 0.7419
# Epoch 60: loss improved from 0.53393 to 0.53346, saving model to checkpoints_ABC\weights.60.hdf5
# 804/804 [==============================] - 1s 934us/step - loss: 0.5335 - accuracy: 0.7418
# Epoch 61/100
# 804/804 [==============================] - 1s 908us/step - loss: 0.5334 - accuracy: 0.7420
# Epoch 62/100
# 804/804 [==============================] - 1s 898us/step - loss: 0.5333 - accuracy: 0.7416
# Epoch 63/100
# 804/804 [==============================] - 1s 965us/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 64/100
# 804/804 [==============================] - 1s 938us/step - loss: 0.5327 - accuracy: 0.7407
# Epoch 65/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5331 - accuracy: 0.7415
# Epoch 65: loss improved from 0.53346 to 0.53278, saving model to checkpoints_ABC\weights.65.hdf5
# 804/804 [==============================] - 1s 911us/step - loss: 0.5328 - accuracy: 0.7416
# Epoch 66/100
# 804/804 [==============================] - 1s 904us/step - loss: 0.5331 - accuracy: 0.7416
# Epoch 67/100
# 804/804 [==============================] - 1s 913us/step - loss: 0.5327 - accuracy: 0.7416
# Epoch 68/100
# 804/804 [==============================] - 1s 894us/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 69/100
# 804/804 [==============================] - 1s 923us/step - loss: 0.5323 - accuracy: 0.7420
# Epoch 70/100
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5324 - accuracy: 0.7417
# Epoch 70: loss improved from 0.53278 to 0.53229, saving model to checkpoints_ABC\weights.70.hdf5
# 804/804 [==============================] - 1s 937us/step - loss: 0.5323 - accuracy: 0.7421
# Epoch 71/100
# 804/804 [==============================] - 1s 969us/step - loss: 0.5322 - accuracy: 0.7423
# Epoch 72/100
# 804/804 [==============================] - 1s 905us/step - loss: 0.5321 - accuracy: 0.7416
# Epoch 73/100
# 804/804 [==============================] - 1s 930us/step - loss: 0.5321 - accuracy: 0.7420
# Epoch 74/100
# 804/804 [==============================] - 1s 903us/step - loss: 0.5319 - accuracy: 0.7430
# Epoch 75/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5307 - accuracy: 0.7439
# Epoch 75: loss improved from 0.53229 to 0.53205, saving model to checkpoints_ABC\weights.75.hdf5
# 804/804 [==============================] - 1s 931us/step - loss: 0.5321 - accuracy: 0.7425
# Epoch 76/100
# 804/804 [==============================] - 1s 924us/step - loss: 0.5318 - accuracy: 0.7424
# Epoch 77/100
# 804/804 [==============================] - 1s 912us/step - loss: 0.5319 - accuracy: 0.7423
# Epoch 78/100
# 804/804 [==============================] - 1s 908us/step - loss: 0.5316 - accuracy: 0.7420
# Epoch 79/100
# 804/804 [==============================] - 1s 909us/step - loss: 0.5315 - accuracy: 0.7420
# Epoch 80/100
# 775/804 [===========================>..] - ETA: 0s - loss: 0.5315 - accuracy: 0.7432
# Epoch 80: loss improved from 0.53205 to 0.53176, saving model to checkpoints_ABC\weights.80.hdf5
# 804/804 [==============================] - 1s 928us/step - loss: 0.5318 - accuracy: 0.7428
# Epoch 81/100
# 804/804 [==============================] - 1s 920us/step - loss: 0.5313 - accuracy: 0.7412
# Epoch 82/100
# 804/804 [==============================] - 1s 925us/step - loss: 0.5313 - accuracy: 0.7421
# Epoch 83/100
# 804/804 [==============================] - 1s 916us/step - loss: 0.5313 - accuracy: 0.7426
# Epoch 84/100
# 804/804 [==============================] - 1s 932us/step - loss: 0.5313 - accuracy: 0.7420
# Epoch 85/100
# 770/804 [===========================>..] - ETA: 0s - loss: 0.5320 - accuracy: 0.7414
# Epoch 85: loss improved from 0.53176 to 0.53115, saving model to checkpoints_ABC\weights.85.hdf5
# 804/804 [==============================] - 1s 933us/step - loss: 0.5312 - accuracy: 0.7420
# Epoch 86/100
# 804/804 [==============================] - 1s 947us/step - loss: 0.5313 - accuracy: 0.7420
# Epoch 87/100
# 804/804 [==============================] - 1s 992us/step - loss: 0.5310 - accuracy: 0.7421
# Epoch 88/100
# 804/804 [==============================] - 1s 913us/step - loss: 0.5311 - accuracy: 0.7428
# Epoch 89/100
# 804/804 [==============================] - 1s 905us/step - loss: 0.5309 - accuracy: 0.7427
# Epoch 90/100
# 761/804 [===========================>..] - ETA: 0s - loss: 0.5300 - accuracy: 0.7433
# Epoch 90: loss improved from 0.53115 to 0.53079, saving model to checkpoints_ABC\weights.90.hdf5
# 804/804 [==============================] - 1s 951us/step - loss: 0.5308 - accuracy: 0.7421
# Epoch 91/100
# 804/804 [==============================] - 1s 927us/step - loss: 0.5309 - accuracy: 0.7421
# Epoch 92/100
# 804/804 [==============================] - 1s 930us/step - loss: 0.5309 - accuracy: 0.7426
# Epoch 93/100
# 804/804 [==============================] - 1s 925us/step - loss: 0.5308 - accuracy: 0.7414
# Epoch 94/100
# 804/804 [==============================] - 1s 927us/step - loss: 0.5305 - accuracy: 0.7421
# Epoch 95/100
# 757/804 [===========================>..] - ETA: 0s - loss: 0.5311 - accuracy: 0.7422
# Epoch 95: loss improved from 0.53079 to 0.53057, saving model to checkpoints_ABC\weights.95.hdf5
# 804/804 [==============================] - 1s 960us/step - loss: 0.5306 - accuracy: 0.7428
# Epoch 96/100
# 804/804 [==============================] - 1s 927us/step - loss: 0.5305 - accuracy: 0.7423
# Epoch 97/100
# 804/804 [==============================] - 1s 926us/step - loss: 0.5306 - accuracy: 0.7428
# Epoch 98/100
# 804/804 [==============================] - 1s 928us/step - loss: 0.5304 - accuracy: 0.7423
# Epoch 99/100
# 804/804 [==============================] - 1s 929us/step - loss: 0.5303 - accuracy: 0.7426
# Epoch 100/100
# 764/804 [===========================>..] - ETA: 0s - loss: 0.5298 - accuracy: 0.7429
# Epoch 100: loss improved from 0.53057 to 0.53046, saving model to checkpoints_ABC\weights.100.hdf5
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7425

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5648 - accuracy: 0.7240 - 264ms/epoch - 986us/step
# Loss: 0.5647953152656555, Accuracy: 0.7239649891853333

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit.history, index=range(1,len(fit.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
